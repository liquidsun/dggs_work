# %%
import sys
import os
import matplotlib.pyplot as plt
import geopandas as gpd
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pickle

# %%
def plot_dggs(dggs_array,columns):
    fig, ax = plt.subplots(1,len(dggs_array),figsize=(20,13),sharex='col')
    for num,frame in enumerate(dggs_array):
        ax[num].axis('off')
        ax[num].margins(0)
        ax[num].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)
        ax[num].set_title(f'Resolution {num}')
        frame.to_crs('EPSG:4326').plot(column=columns, ax=ax[num])
        boundary.plot(color=None, edgecolor='r',linewidth = 0.3,ax=ax[num])

# %%
def plot_dggs_cor(dggs_array,columns):
    fig, ax = plt.subplots(1,len(dggs_array),figsize=(20,13),sharex='col')
    for num,frame in enumerate(dggs_array):
        frame[columns] = frame[columns].astype('int')
        ax[num].axis('off')
        ax[num].margins(0)
        ax[num].tick_params(left=False, labelleft=False, bottom=False, labelbottom=False)
        ax[num].set_title(f'Resolution {num}')
        if frame.crs == None:
            frame=frame.set_crs('EPSG:4326')
        frame.to_crs('EPSG:4326').plot(column=columns, ax=ax[num])
        boundary.plot(color=None, edgecolor='r',linewidth = 0.3,ax=ax[num])

# %%
area = gpd.read_file(r'd:\UT\2Semester\Planning Project\task2\data\shp\Tartu_area.shp')
area = area.to_crs('EPSG:4326')
boundary =  area.boundary

# %%
## ELEVATION

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\ISEA4T_elev.pkl','rb') as f:
    dfs_4T = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\ISEA3H_elev.pkl','rb') as f:
    dfs_3H = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\s2_elev.pkl','rb') as f:
    dfs_s2 = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\rHpix_elev.pkl','rb') as f:
    dfs_rHpix = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\H3_elev.pkl','rb') as f:
    dfs_h3 = pickle.load(f)

# %%
plot_dggs(dfs_4T,'elevation')
#plt.savefig(r'd:\30_days\h3_elev.png', bbox_inches="tight", pad_inches=0.1, dpi=600)

# %%
plot_dggs(dfs_3H,'elevation')

# %%
plot_dggs(dfs_s2,'elevation')

# %%
plot_dggs(dfs_rHpix,'elevation')

# %%
plot_dggs(dfs_h3,'elevation')

# %%
## land cover

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\ISEA4T_cor.pkl','rb') as f:
    dfs_4T = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\ISEA3H_cor.pkl','rb') as f:
    dfs_3H = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\s2_cor.pkl','rb') as f:
    dfs_s2 = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\rHpix_cor.pkl','rb') as f:
    dfs_rHpix = pickle.load(f)

# %%
with open(r'd:\UTCloud\DGGS\grids\tartu_series\H3_cor.pkl','rb') as f:
    dfs_h3 = pickle.load(f)

# %%
plot_dggs_cor(dfs_4T,'code_18')
#plt.savefig(r'd:\30_days\h3_elev.png', bbox_inches="tight", pad_inches=0.1, dpi=600)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-dbbc116ef8e8> in <module>
# ----> 1 plot_dggs_cor(dfs_4T,'code_18')
#       2 #plt.savefig(r'd:\30_days\h3_elev.png', bbox_inches="tight", pad_inches=0.1, dpi=600)
#
# <ipython-input-109-ccb804a1a0e8> in plot_dggs_cor(dggs_array, columns)
#       9         if frame.crs == None:
#      10             frame=frame.set_crs('EPSG:4326')
# ---> 11         frame.to_crs('EPSG:4326').plot(column=columns, ax=ax[num])
#      12         boundary.plot(color=None, edgecolor='r',linewidth = 0.3,ax=ax[num])
#
# ~\Anaconda3\envs\dggs\lib\site-packages\geopandas\geodataframe.py in plot(self, *args, **kwargs)
#     919         from there.
#     920         """
# --> 921         return plot_dataframe(self, *args, **kwargs)
#     922
#     923     plot.__doc__ = plot_dataframe.__doc__
#
# ~\Anaconda3\envs\dggs\lib\site-packages\geopandas\plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     822             ax.get_figure().colorbar(n_cmap, **legend_kwds)
#     823
# --> 824     plt.draw()
#     825     return ax
#     826
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\pyplot.py in draw()
#     851     the current figure.
#     852     """
# --> 853     gcf().canvas.draw_idle()
#     854
#     855
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2010         if not self._is_idle_drawing:
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#    2014     @cbook.deprecated("3.2")
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1838                 ax.apply_aspect(pos)
#    1839             else:
# -> 1840                 ax.apply_aspect()
#    1841
#    1842             for child in ax.get_children():
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1605             box_aspect = aspect * self.get_data_ratio()
#    1606             pb = position.frozen()
# -> 1607             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1608             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1609             return
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     552         """
#     553         if box_aspect <= 0 or fig_aspect <= 0:
# --> 554             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     555         if container is None:
#     556             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\dggs\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda3\envs\dggs\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda3\envs\dggs\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1838                 ax.apply_aspect(pos)
#    1839             else:
# -> 1840                 ax.apply_aspect()
#    1841
#    1842             for child in ax.get_children():
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1605             box_aspect = aspect * self.get_data_ratio()
#    1606             pb = position.frozen()
# -> 1607             pb1 = pb.shrunk_to_aspect(box_aspect, pb, fig_aspect)
#    1608             self._set_position(pb1.anchored(self.get_anchor(), pb), 'active')
#    1609             return
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\transforms.py in shrunk_to_aspect(self, box_aspect, container, fig_aspect)
#     552         """
#     553         if box_aspect <= 0 or fig_aspect <= 0:
# --> 554             raise ValueError("'box_aspect' and 'fig_aspect' must be positive")
#     555         if container is None:
#     556             container = self
#
# ValueError: 'box_aspect' and 'fig_aspect' must be positive

# %%
plot_dggs_cor(dfs_3H[1],'code_18')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-115-fee2e57e5bf0> in <module>
# ----> 1 plot_dggs_cor(dfs_3H[1],'code_18')
#
# <ipython-input-114-ccb804a1a0e8> in plot_dggs_cor(dggs_array, columns)
#       1 def plot_dggs_cor(dggs_array,columns):
# ----> 2     fig, ax = plt.subplots(1,len(dggs_array),figsize=(20,13),sharex='col')
#       3     for num,frame in enumerate(dggs_array):
#       4         frame[columns] = frame[columns].astype('int')
#       5         ax[num].axis('off')
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1290                        gridspec_kw=gridspec_kw)
#    1291     return fig, axs
#    1292
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
# -> 1524                           subplot_kw=subplot_kw))
#    1525
#    1526     @staticmethod
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     335                 subplot_kw["sharey"] = shared_with[sharey]
#     336                 axarr[row, col] = figure.add_subplot(
# --> 337                     self[row, col], **subplot_kw)
#     338
#     339         # turn off redundant tick labeling
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# -> 1404         return self._add_axes_internal(key, ax)
#    1405
#    1406     def _add_axes_internal(self, key, ax):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in _add_axes_internal(self, key, ax)
#    1407         """Private helper for `add_axes` and `add_subplot`."""
#    1408         self._axstack.add(key, ax)
# -> 1409         self.sca(ax)
#    1410         ax._remove_method = self.delaxes
#    1411         self.stale = True
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in sca(self, a)
#    2067     def sca(self, a):
#    2068         """Set the current axes to be *a* and return *a*."""
# -> 2069         self._axstack.bubble(a)
#    2070         self._axobservers.process("_axes_change_event", self)
#    2071         return a
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\figure.py in bubble(self, a)
#     102         stack, to the top.
#     103         """
# --> 104         return super().bubble(self._entry_from_axes(a))
#     105
#     106     def add(self, key, a):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\cbook\__init__.py in bubble(self, o)
#     626                 top_elements.append(elem)
#     627             else:
# --> 628                 self.push(elem)
#     629         for _ in top_elements:
#     630             self.push(o)
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\cbook\__init__.py in push(self, o)
#     584         *o* is returned.
#     585         """
# --> 586         self._elements = self._elements[:self._pos + 1] + [o]
#     587         self._pos = len(self._elements) - 1
#     588         return self()
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x000001A3C19D5558> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\envs\dggs\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\Anaconda3\envs\dggs\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\Anaconda3\envs\dggs\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ~\Anaconda3\envs\dggs\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1253         if minor:
#    1254             return self.get_minorticklabels()
# -> 1255         return self.get_majorticklabels()
#    1256
#    1257     def get_majorticklines(self):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1205     def get_majorticklabels(self):
#    1206         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1207         ticks = self.get_major_ticks()
#    1208         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1209         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1380         while len(self.majorTicks) < numticks:
#    1381             # Update the new tick label properties from the old.
# -> 1382             tick = self._get_tick(major=True)
#    1383             self.majorTicks.append(tick)
#    1384             tick.gridline.set_visible(self._gridOnMajor)
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2301         else:
#    2302             tick_kw = self._minor_tick_kw
# -> 2303         return YTick(self.axes, 0, major=major, **tick_kw)
#    2304
#    2305     def set_label_position(self, position):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     498             xdata=[1], ydata=[0],
#     499             transform=self.axes.get_yaxis_transform(which="tick2"),
# --> 500             marker=self._tickmarkers[1],
#     501         )
#     502         self.gridline.set(
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1155             arguments.
#    1156         """
# -> 1157         self._marker.set_marker(marker)
#    1158         self.stale = True
#    1159
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\markers.py in _set_tickright(self)
#     738
#     739     def _set_tickright(self):
# --> 740         self._transform = Affine2D().scale(1.0, 1.0)
#     741         self._snap_threshold = 1.0
#     742         self._filled = False
#
# ~\Anaconda3\envs\dggs\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1844             # A bit faster than np.identity(3).
#    1845             matrix = IdentityTransform._mtx.copy()
# -> 1846         self._mtx = matrix.copy()
#    1847         self._invalid = 0
#    1848
#
# KeyboardInterrupt:

# %%
plot_dggs_cor(dfs_s2,'code_18')

# %%
plot_dggs_cor(dfs_rHpix,'code_18')

# %%
plot_dggs_cor(dfs_h3,'code_18')
